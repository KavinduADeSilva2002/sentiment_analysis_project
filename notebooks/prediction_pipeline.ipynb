# %% [markdown]
# # Sentiment Analysis Prediction Pipeline
# This notebook demonstrates how to use the trained model for making predictions on new text.

# %%
import sys
import os

# Add project root to path so we can import from src
sys.path.append(os.path.abspath('..'))

from src.model_utils import predict_sentiment

# %%
txt = 'This is the best product I have ever bought! Highly recommended.'
sentiment = predict_sentiment(txt)
print(f"Text: {txt}")
print(f"Sentiment: {sentiment}")

# %%
txt = 'Absolutely terrible service. I am very disappointed.'
sentiment = predict_sentiment(txt)
print(f"Text: {txt}")
print(f"Sentiment: {sentiment}")

# %%
test_sentences = [
    "I love my new iPhone!",
    "The software update is full of bugs.",
    "The camera quality is amazing.",
    "I hate this company."
]

for s in test_sentences:
    print(f"{predict_sentiment(s)}: {s}")
